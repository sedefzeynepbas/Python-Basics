# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("USvideos.csv")

# %%
dataset
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 23357  pH7VfJDq7f4      18.12.03
# 23358  hV-yHbbrKRA      18.12.03
# 23359  CwKp6Xhy3_4      18.12.03
# 23360  vQiiNGllGQo      18.12.03
# 23361  2afSbqlp5HU      18.12.03
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# ...

# %%
dataset.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
newdataset1 = dataset.drop(["video_id","trending_date"],axis=1)

# %%
newdataset1
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id              publish_time  \
# 0                 CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1              LastWeekTonight           24  2017-11-13T07:30:00.000Z
# ...

# %%
newdataset1.to_csv("USVideosNew.csv")#yeni dosya açıldı

# %%
print(""
,
0,WE WANT
1,The Trump Presidenc
2,"Racist Superman |
"")#ama bu şekilde indexler ve virgüller de geliyo onları istemiyoruz daha düzgün gözüksün diye
# Out:
#   File "C:\Users\BSS5BU\AppData\Local\Temp/ipykernel_2384/3380921779.py", line 3
#     0,WE WANT
#          ^
# SyntaxError: invalid syntax

# %%
newdataset1.to_csv("USVideosNew2.csv",index=False)#yeni dosya açıldı ve indeksleri almadı

# %%
excelset = pd.read_excel("excelfile.xlsx")

# %%
excelset["Column5"]="Tinki vinki dipsi udemy".split(" ")

# %%
excelset
# Out:
#   Unnamed: 0  Column1  Column2  Column3  Column4 Column5
# 0     Index1       10       50       90      130   Tinki
# 1     Index2       20       60      100      140   vinki
# 2     Index3       30       70      110      150   dipsi
# 3     Index4       40       80      120      160   udemy

# %%
excelset.to_excel("newExcel.xlsx")

# %%
new = pd.read_html("http://www.contextures.com/xlSampleData01.html",header = 0)#olmuyor................
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\Program Files\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# C:\Program Files\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ...
