# %%
import os
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\BSS5BU\Desktop\sedef\python\jupyter_files

# %%
os.chdir("C:\\Users\\BSS5BU\\Desktop")
print(os.getcwd())
# Out:
# C:\Users\BSS5BU\Desktop

# %%
os.chdir("C:\\Users\\BSS5BU\\Desktop")
print(os.listdir())
# Out:
# ['Anaconda Navigator (Anaconda3).lnk', 'bilgiler.txt', 'BOSCH', 'CPTM.url', 'daily_tasks.txt', 'desktop.ini', 'dhjkgjf.txt', 'fd.docx', 'New Text Document.txt', 'PyCharm Community Edition 2022.3.1.lnk', 'pycharm_files', 'Report', 'sayı_tabanları.png', 'sedef']

# %%
for i in os.listdir():
    print(i)
# Out:
# Anaconda Navigator (Anaconda3).lnk
# bilgiler.txt
# BOSCH
# CPTM.url
# daily_tasks.txt
# desktop.ini
# dhjkgjf.txt
# fd.docx
# New Text Document.txt
# PyCharm Community Edition 2022.3.1.lnk
# pycharm_files
# Report
# sayı_tabanları.png
# sedef

# %%
os.chdir("C:\\Users\\BSS5BU\\Desktop\\sedef\\python\\jupyter_files")
print(os.getcwd())
# Out:
# C:\Users\BSS5BU\Desktop\sedef\python\jupyter_files

# %%
os.mkdir("Deneme1")

# %%
os.mkdir("Deneme1/Deneme2/Deneme3")#Deneme 1i altına Deneme2 onun altına Deneme3 oluşturdu
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20924/2504381208.py in <module>
# ----> 1 os.mkdir("Deneme1/Deneme2/Deneme3")#Deneme 1i altına Deneme2 onun altına Deneme3 oluşturdu
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Deneme1/Deneme2/Deneme3'

# %%
os.mkdir("Deneme1/Deneme2/Deneme3")#tekrar çalıştırınca bu hata geliyor
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20924/1377482203.py in <module>
# ----> 1 os.mkdir("Deneme1/Deneme2/Deneme3")#tekrar çalıştırınca bu hata geliyor
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Deneme1/Deneme2/Deneme3'

# %%
os.rmdir("Deneme1/Deneme2/Deneme3")#Deneme3 silindi

# %%
os.mkdir("Deneme1/Deneme2/Deneme3")

# %%
os.removedirs("Deneme1/Deneme2/Deneme3")

# %%
os.rename("test.txt","test2.txt")#test diye bir dosya oluşturdum ismini test2ye değiştiriyorum

# %%
#Dosya özellikleri

# %%
print(os.stat("test2.txt"))#st_mtime dosyanın değiştirilme zamanı
# Out:
# os.stat_result(st_mode=33206, st_ino=1970324837081242, st_dev=542340901, st_nlink=1, st_uid=0, st_gid=0, st_size=19, st_atime=1676895759, st_mtime=1676895691, st_ctime=1676895670)

# %%
print(os.stat("test2.txt").st_mtime)
# Out:
# 1676895691.3595433

# %%
from datetime import datetime

# %%
print(datetime.fromtimestamp(os.stat("test2.txt").st_mtime))
# Out:
# 2023-02-20 15:21:31.359543

# %%
#os.walk ile demet döndürüyor gezerek

# %%
print(os.walk("C:\\Users\\BSS5BU\\Desktop"))
# Out:
# <generator object _walk at 0x000002A907251510>

# %%
for i in os.walk("C:\\Users\\BSS5BU\\Desktop"):
    print(i)
# Out:
# ('C:\\Users\\BSS5BU\\Desktop', ['BOSCH', 'pycharm_files', 'Report', 'sedef'], ['Anaconda Navigator (Anaconda3).lnk', 'bilgiler.txt', 'CPTM.url', 'daily_tasks.txt', 'desktop.ini', 'dhjkgjf.txt', 'fd.docx', 'New Text Document.txt', 'PyCharm Community Edition 2022.3.1.lnk', 'sayı_tabanları.png'])
# ...

# %%
for klasör_yolu,klasör_isimleri,dosya_isimleri in os.walk("C:\\Users\\BSS5BU\\Desktop"):
    print("Klasör yolu", klasör_yolu)
    print("Klasör isimleri", klasör_isimleri)
    print("Dosya isimleri", dosya_isimleri)
    print("*****************************************")
# Out:
# Klasör yolu C:\Users\BSS5BU\Desktop
# Klasör isimleri ['BOSCH', 'pycharm_files', 'Report', 'sedef']
# Dosya isimleri ['Anaconda Navigator (Anaconda3).lnk', 'bilgiler.txt', 'CPTM.url', 'daily_tasks.txt', 'desktop.ini', 'dhjkgjf.txt', 'fd.docx', 'New Text Document.txt', 'PyCharm Community Edition 2022.3.1.lnk', 'sayı_tabanları.png']
# *****************************************
# Klasör yolu C:\Users\BSS5BU\Desktop\BOSCH
# Klasör isimleri []
# ...

# %%
for klasör_yolu,klasör_isimleri,dosya_isimleri in os.walk("C:\\Users\\BSS5BU\\Desktop"):
    for i in dosya_isimleri:
        print(i)
# Out:
# Anaconda Navigator (Anaconda3).lnk
# bilgiler.txt
# CPTM.url
# daily_tasks.txt
# desktop.ini
# dhjkgjf.txt
# fd.docx
# New Text Document.txt
# PyCharm Community Edition 2022.3.1.lnk
# sayı_tabanları.png
# 2FA Virtual Smart Card.lnk
# ADM Portalı.url
# Bilgi Güvenligi.url
# Bosch HSE.url
# Bosch-Printer Management.lnk
# BuP1 Kalite Dokumanları.url
# ClickShare.lnk
# Connect PFE-TR.url
# CPTM.url
# eDrawings 2021 x64 Edition.lnk
# eForms NG.lnk
# Google Chrome.lnk
# HR Global.url
# ICO Problem Bildirimi.url
# IT Service Portal.url
# IT Talep Havuzu.url
# koppler_raff_test_IKT.docx
# Microsoft Teams.lnk
# Minitab Statistical Software.lnk
# Mozilla Firefox.lnk
# My i-Buy.url
# MyTime.url
# MyTimeRequest.url
# Power Automate Desktop.lnk
# Q-Reports.URL
# SAP Logon.lnk
# SOLIDWORKS 2021.lnk
# SOLIDWORKS Composer 2021.lnk
# SOLIDWORKS Composer Player 2021.lnk
# SOLIDWORKS Visualize 2021.lnk
# TalentHub.url
# Teamcenter Vis Professional 13.1 64-bit.lnk
# ...

# %%
for klasör_yolu,klasör_isimleri,dosya_isimleri in os.walk("C:\\Users\\BSS5BU\\Desktop"):
    for i in dosya_isimleri:
        if i.endswith(".txt"):
            print(i)
# Out:
# bilgiler.txt
# daily_tasks.txt
# dhjkgjf.txt
# New Text Document.txt
# emails.txt
# geçenler.txt
# harf_notları.txt
# isimler.txt
# kalanlar.txt
# kedilervetakımlar.txt
# kuru_mama_takımı.txt
# metin_inceleme.txt
# notlar.txt
# numaralar.txt
# tarihler.txt
# yaş_mama_takımı.txt
# ödül_takımı.txt
# üç_notlar.txt
# şiir.txt
# LICENSE_PYTHON.txt
# CREDITS.txt
# extend.txt
# HISTORY.txt
# NEWS.txt
# NEWS2x.txt
# README.txt
# TODO.txt
# README.txt
# README.txt
# Grammar.txt
# PatternGrammar.txt
# README.txt
# top_level.txt
# vendor.txt
# dependency_links.txt
# entry_points.txt
# SOURCES.txt
# top_level.txt
# dependency_links.txt
# entry_points.txt
# requires.txt
# SOURCES.txt
# top_level.txt
# dependency_links.txt
# entry_points.txt
# requires.txt
# SOURCES.txt
# top_level.txt
# html40colors.txt
# namedcolors.txt
# webcolors.txt
# websafe.txt
# rgb.txt
# xlicense.txt
# LICENSE_PYTHON.txt
# CREDITS.txt
# extend.txt
# HISTORY.txt
# NEWS.txt
# NEWS2x.txt
# README.txt
# TODO.txt
# README.txt
# ...
